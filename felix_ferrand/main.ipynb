# %% [markdown]
# # Félix Ferrand

# %%
import cv2, json, requests
import numpy as np
import matplotlib.pyplot as plt

def detect_faces(img):
    r = requests.post(
        url='http://127.0.0.1:5000/predict',
        json={'img' : '../' + img }
    )
    faces = np.array(r.json()["faces"])
    img = cv2.imread(img)
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roicolor = img[y:y+h, x:x+w]
    plt.grid(None)   
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)

# %%
detect_faces('opencv/img1.jpg')

# %%
detect_faces('opencv/img2.jpg')

# %%
detect_faces('opencv/img3.jpg')
